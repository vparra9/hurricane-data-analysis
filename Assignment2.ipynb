# %% [markdown]
# **CAP 4773: Homework Assignment 2**
#
# **Due on Canvas by Sunday, September 27, 2026 at 11:59pm**

# %% [markdown]
# **Place name here:**

# %% [markdown]
# **Preliminary instructions**
#
# All analyses must be performed in Python using the **`plotnine`** and **`tidypandas`** libraries that we discussed in class. Fill in all your solutions in the appropriate text or code cells provided in this Python notebook, and then upload a HTML-converted copy of your Python notebook solution to Canvas. **Only HTML copies of this notebook will be graded.** Instructions on how to convert Python notebooks to HTML in Google Colab are provided at the bottom of this assignment.
#
#
# To install the **`plotnine`** library with all its dependencies as well as **`tidypandas`**, execute the following code.

# %%
pip install --quiet plotnine[all] tidypandas

# %% [markdown]
# Note that the argument **`--quiet`** ensures that the output from the installation is silent.
#
# To load the **`plotnine`** and **`tidypandas`** libraries, execute the following code.

# %%
from plotnine import *
from tidypandas import tidyframe

# %% [markdown]
# **Brief overview of assignment**
#
# In this assignment you will be analyzing the **`storms`** data frame that contains data on storms from the National Oceanic Atmospheric Administration (NOAA) Atlantic hurricane database. You can read more about this dataset in its [documentation](https://dplyr.tidyverse.org/reference/storms.html).

# %% [markdown]
# Some questions require you to use plotting functions that we have never discussed in class, and so you must look at the **`plotnine`** [documentation](https://plotnine.org/) carefully.
#
# Below, is code that can be executed to install the **`pandas`** library, as we will use this library to import the **`storms`** data frame from a URL. This is the only spot that we are using **`pandas`** code within this assignment, and the remainder of the code must follow **`tidypandas`** and **`plotnine`** syntax. The data frame is stored as a comma-separated values (CSV) file, which we can be read using the **`pandas`** function **`read_csv()`** from a URL. We will further discuss reading external data files in CSV format in Module 5.

# %%
pip install --quiet pandas

# %% [markdown]
# To load the **`storms`** data fame from its URL source, execute the following code.

# %%
import pandas
storms = pandas.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/dplyr/storms.csv")
storms
# Out:
#        rownames    name  year  month  day  hour   lat  long  \
# 0             1     Amy  1975      6   27     0  27.5 -79.0
# 1             2     Amy  1975      6   27     6  28.5 -79.0
# 2             3     Amy  1975      6   27    12  29.5 -79.0
# 3             4     Amy  1975      6   27    18  30.5 -79.0
# 4             5     Amy  1975      6   28     0  31.5 -78.8
# ...         ...     ...   ...    ...  ...   ...   ...   ...
# 19532     19533  Nicole  2022     11   10    19  29.2 -83.0
# 19533     19534  Nicole  2022     11   11     0  30.1 -84.0
# 19534     19535  Nicole  2022     11   11     6  31.2 -84.6
# 19535     19536  Nicole  2022     11   11    12  33.2 -84.6
# 19536     19537  Nicole  2022     11   11    18  35.4 -83.8
#
#                     status  category  wind  pressure  \
# 0      tropical depression       NaN    25      1013
# 1      tropical depression       NaN    25      1013
# 2      tropical depression       NaN    25      1013
# ...

# %% [markdown]
# **1. [20%]** Conditioning on storm observations that are hurricanes, for each unique storm name, compute the number of sampled observations for that storm, the maximum category of the storm, the average wind speed of the storm, and the average air pressure of the storm. After calculating these measurements, generate a scatter plot of average air pressure as a function of average wind speed. Fill each plotted point with the color associated with the storm's maximum category, and plot the size of the point proportional to the number of sampled observations for that storm. Also, set the transparency alpha value of each point to 0.8. Overlay a single smoothing trend curve with 99% confidence intervals. Moreover, set the *x*-axis label to "Wind speed (knots)" and the *y*-axis label to "Air pressure (millibars)". Finally, set the background to be white with dark grid lines rather than the default gray with white grid lines.

# %% [markdown]
# **2. [10%]** From your solution to Question 1, does there appear to be a relationship between average air pressure and average wind speed? If so, then what what is the relationship? Does the maximum storm category broadly follow this trend? Use a search engine to research this trend, and provide an explanation for the data based on what you have researched about hurricanes.

# %% [markdown]
# **Provide answer here:**

# %% [markdown]
# **3. [20%]** Conditioning on storm observations that are hurricanes, compute a new feature **`day_of_year`** that is calculated as **`month - 1 + day / 31`**, which results in a value between 0 and 12 and represents a fraction of the 12 months of the year and corresponds to a unique day of the year. After calculating these measurements, generate a scatter plot of air pressure as a function of the day of the year (the feature just computed). Fill each plotted point with the color associated with the observed category of the storm. Also, set the transparency alpha value of each point to 0.25. On top of these points, add a layer for a two-dimensional density (contour) plot, depicting the shape of the distributions in the form of contour rings. Change the plotted line size of this density plot using the argument **`size = 1`** to make the lines thicker. Moreover, set the *x*-axis label to "Day of year" and the *y*-axis label to "Air pressure (millibars)". Finally, set the background to be white with dark grid lines rather than the default gray with white grid lines.

# %% [markdown]
# **4. [5%]** From your solution to Question 3, what month(s) tend to have the greatest density of hurricanes, and does this pattern track well with the storm category as well? Explain why adding the two-dimensional density plot was valuable here, in addition to the scatter plot.

# %% [markdown]
# **Provide answer here:**

# %% [markdown]
# **5. [15%]** Conditioning on storm observations that are hurricanes, for each month, compute the number of sampled storm observations and the average category of storms. After calculating these measurements, generate a bar plot of average storm category as a function of month. This bar plot, in which we can customize what is plotted on the *y*-axis can be obtained by using the **`geom_col()`** function instead of **`geom_bar()`**. Fill each plotted bar with the color associated with the number of sampled storm observations in the given month. Moreover, set the *x*-axis label to "Month" and the *y*-axis label to "Average storm category". Finally, set the background to be white with dark grid lines rather than the default gray with white grid lines.

# %% [markdown]
# **6. [5%]** From your solution to Question 5, what month has the highest average storm category? Which month has the greatest number of hurricanes? Do these months match? Are these results consistent with your findings from Questions 3 and 4?

# %% [markdown]
# **Provide answer here:**

# %% [markdown]
# **7. [15%]** Condioning on storm observations that are hurricanes, for each month, compute the number of sampled storm observations and the median wind speed. After calculating these measurements, generate a bar plot of the number of sampled storms as a function of month. This bar plot, in which we can customize what is plotted on the *y*-axis can be obtained using the same plotting function described in Question 5. Fill each plotted bar with the color associated with the storm's median wind speed. Moreover, set the *x*-axis label to "Month" and the *y*-axis label to "Number of storms". Finally, set the background to be white with dark grid lines rather than the default gray with white grid lines.

# %% [markdown]
# **8. [10%]** From your solution to Question 7, does the month with the greatest median wind speed align with the month with the greatest number of hurricanes? Using a search engine, research hurricanes. Does this pattern align with the months that typically have the greatest number of storms as well as the strongest storms?

# %% [markdown]
# **Provide answer here:**

# %% [markdown]
# **Exporting this Python notebook to HTML.** We have reviewed in class how to export a Python notebook to HTML. However, for a reminder, you can see the following [answer](https://stackoverflow.com/questions/53460051/convert-ipynb-notebook-to-html-in-google-colab) on Stack Overflow as a reminder. You can use the Python notebook cell below to paste in the code to export to HTML.
